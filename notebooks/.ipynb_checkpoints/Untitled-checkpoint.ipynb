# %%
using LinearAlgebra
basepath = "./"
srcpath = basepath*"./"
datapath = basepath*"mcmc_data/short_timescale/input/"
outpath = basepath*"mcmc_data/short_timescale/output/"
inputpath = basepath*"mcmc_data/short_timescale/input/"
include(srcpath*"../src/celerite.jl")
include(srcpath*"../TransitModel/transit.jl")

## Define a new multivariate Distribution type for Mamba.
## The definition must be placed within an unevaluated quote block.
extensions = quote

    ## Load needed packages and import methods to be extended
    using Distributions
    import Distributions: length, insupport, _logpdf

    ## Type declaration
    mutable struct CeleriteDist <: ContinuousMultivariateDistribution
        t::Array{Real, 1}
        c::Array{Real, 1}
        log_s::Real
        log_q::Real
        log_w::Real
        log_wn::Array{Real, 1}
        mu::Array{Real, 1}
        gp::celerite.Celerite
        
        function CeleriteDist(t, log_s, log_q, log_w; log_wn=-12, c=[1], mu=zeros(Base.length(c), Base.length(t)))
            gp = celerite.Celerite(celerite.SHOTerm(log_s, log_q, log_w), broadcast(*, c, c'))
            new(t, c, log_s, log_q, log_w, log_wn, mu, gp)
        end
    end

    ## The following method functions must be implemented

    ## Dimension of the distribution
    length(d::CeleriteDist) = length(d.t)*length(d.c)

    ## Logical indicating whether x is in the support
    function insupport(d::CeleriteDist, x::AbstractVector{T}) where {T<:Real}
        length(d) == length(x) && all(isfinite.(x))
    end
    
    function _logpdf(d::CeleriteDist, x::AbstractVector{T}) where {T<:Real}
        m = Base.length(d.c)
        n = length(d.t)
        wn_vec = zeros(n*m)
	for i in 1:m
            wn_vec[i:m:end] .= exp.(d.log_wn[i])
	end
        try
            celerite.compute!(d.gp, d.t, wn_vec)
            return celerite.log_likelihood(d.gp, x.-d.mu)
        catch
            return -Inf 
        end
    end
    
    function _rand!(d::CeleriteDist, x::AbstractVector{T}) where {T<:Real}
        m = Base.length(d.c)
        n = length(d.t)
        wn_vec = zeros(n*m)
        for i in 1:m
            wn_vec[i:m:end] .= exp(d.log_wn[i])
        end
        celerite.compute!(d.gp, d.t, wn_vec)
        u = randn(Base.length(d.t)*Base.length(d.c))
        x[:] = celerite.simulate_gp(d.gp, u)
        for i in 1:m
            x[i:m:end] .+= d.mu[i,:]
        end
    end
    
    mean(d::CeleriteDist) = convert(Array{Real, 2}, d.mu)
    
end

using Mamba
eval(extensions)
# Out:
# mean (generic function with 1 method)

# %%
using DelimitedFiles
#codefile = inputpath*"codes.in"
paramfile = inputpath*"params_poly.in"
runcodes = ["1"]
params = readdlm(paramfile)
paramdict = Dict(runcodes[i] => params[i,:] for i in 1:length(runcodes))

# build model 

TransitModel = Model(

    # defines the probability of y given mu and sig as a multivariate normal likelihood function 
    y = Stochastic(1,
        (t, c, log_s, log_w, log_q, log_wn, trans) -> CeleriteDist(t, log_s, log_q, log_w, log_wn=log_wn, mu=trans, c=[c[1], c[2]]),
        false
    ),
    
    trans = Logical(1,
        (t0, b0, rp, d, u, t) -> transit(t, t0, b0, rp, d, u)[1],
        false,
    ),
    
    # transit parameters
    t0 = Stochastic(
        () -> Uniform(-1, 1)
    ),
    b0 = Stochastic(
        () -> Uniform(0, 1)
    ),
   
    log_rp = Stochastic(
        () -> Uniform(-20, 0),
        false
    ),
    rp = Logical(
        (log_rp) -> exp(log_rp)
    ),
    d = Stochastic(
        () -> Uniform(0, 10)
    ),    
    q = Stochastic(1,
        () -> UnivariateDistribution[Uniform(0, 1), Uniform(0, 1)],
        false
    ),
    u = Logical(1,
        (q) -> [2*sqrt(q[1])*q[2], sqrt(q[1])*(1-2*q[2])]
    ),

    #noise parameters
    log_s = Stochastic(
        () -> Uniform(-30, 0)
    ),
    log_q = Stochastic(
        () -> Uniform(-10, 10)
    ),
    log_w = Stochastic(
        () -> Uniform(-10, 10)
    ),
    log_wn = Stochastic(1,
        () -> UnivariateDistribution[Uniform(-40, 10), Uniform(-40, 10)]
    ),
    c = Stochastic(1,
        () -> UnivariateDistribution[Uniform(0, 10), Uniform(0, 10)]
    )
)

# define the sampling scheme: No U-Turn Sampling for the three parameters 
scheme = [AMWG([:t0, :b0, :log_rp, :d, :q, :log_s, :log_q, :log_w, :log_wn, :c], 0.1*ones(13))]

# define the initial values for the walkers 
epsilon = 1e-8
nchains = 1

function f(code)
    p = paramdict[code]
    log_wn1, log_wn2, c1, c2, b0, rp, d, q1, q2, log_s, log_q, log_w, t0 = p
    transfile = datapath*"transit_poly_"*code
    fluxdata = readdlm(transfile)
                
    data = Dict{Symbol, Any}(
        :t => fluxdata[:,1],
        :y => vec(permutedims(fluxdata[:, 2:end]))
    )
    inits = [
        Dict{Symbol, Any}(
            :y => data[:y],
                        
            #transit parameters
            :t0 => t0 + epsilon*randn(),
            :b0 => b0 + epsilon*randn(),
            :log_rp => log(rp) + epsilon*randn(),
            :d => d + epsilon*randn(),
            :q => [q1, q2] + epsilon*randn(2),
            
            #noise parameters
            :log_s => log_s + epsilon*randn(),
            :log_q => log_q + epsilon*randn(),
            :log_w => log_w + epsilon*randn(),
            :log_wn => [log_wn1, log_wn2] + epsilon*randn(2),
            :c => [c1, c2] + epsilon*randn(2)
        )
        for i in 1:nchains
    ]
                
    setsamplers!(TransitModel, scheme)
    simfile = outpath*"simpoly"*code*".jls"
    sim = mcmc(TransitModel, data, inits, 10, burnin=0, chains=nchains)
    write(simfile, sim)
end
map(f, runcodes)
# Out:
# MCMC Simulation of 10 Iterations x 1 Chain...
# UndefVarError: log_wn not defined
#
# Stacktrace:
#  [1] _logpdf(::CeleriteDist, ::Array{Float64,1}) at ./In[1]:50
#  [2] logpdf_sub(::CeleriteDist, ::Array{Float64,1}, ::Bool) at /Users/tgordon/.julia/packages/Distributions/0Wogo/src/multivariates.jl:195
#  [3] logpdf(::ArrayStochastic{1}, ::Array{Float64,1}, ::Bool) at /Users/tgordon/.julia/packages/Mamba/674DT/src/model/dependent.jl:220
#  [4] logpdf at /Users/tgordon/.julia/packages/Mamba/674DT/src/model/dependent.jl:216 [inlined] (repeats 2 times)
#  [5] logpdf!(::Model, ::Array{Float64,1}, ::Int64, ::Bool) at /Users/tgordon/.julia/packages/Mamba/674DT/src/model/simulation.jl:87
#  [6] logpdf!(::Mamba.SamplingBlock, ::Array{Float64,1}) at /Users/tgordon/.julia/packages/Mamba/674DT/src/samplers/sampler.jl:102
#  [7] (::getfield(Mamba, Symbol("##199#201")))(::Array{Float64,1}) at /Users/tgordon/.julia/packages/Mamba/674DT/src/samplers/amwg.jl:52
#  [8] amwg_sub!(::SamplerVariate{Mamba.AMWGTune}, ::getfield(Mamba, Symbol("##199#201"))) at /Users/tgordon/.julia/packages/Mamba/674DT/src/samplers/amwg.jl:95
#  [9] #sample!#203(::Bool, ::Function, ::SamplerVariate{Mamba.AMWGTune}, ::Function) at /Users/tgordon/.julia/packages/Mamba/674DT/src/samplers/amwg.jl:68
#  [10] #sample! at ./none:0 [inlined]
#  [11] (::getfield(Mamba, Symbol("##198#200")){Symbol,Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},Array{Float64,1}})(::Model, ::Int64) at /Users/tgordon/.julia/packages/Mamba/674DT/src/samplers/amwg.jl:52
#  [12] (::getfield(Main, Symbol("##125#126")))(::Model, ::Int64) at ./none:0
#  [13] sample!(::Model, ::Int64) at /Users/tgordon/.julia/packages/Mamba/674DT/src/model/simulation.jl:99
#  [14] sample!(::Model) at /Users/tgordon/.julia/packages/Mamba/674DT/src/model/simulation.jl:94
#  [15] mcmc_worker!(::Array{Any,1}) at /Users/tgordon/.julia/packages/Mamba/674DT/src/model/mcmc.jl:76
#  [16] iterate at ./generator.jl:47 [inlined]
#  [17] _collect(::Array{Array{Any,1},1}, ::Base.Generator{Array{Array{Any,1},1},typeof(Mamba.mcmc_worker!)}, ::Base.EltypeUnknown, ::Base.HasShape{1}) at ./array.jl:632
#  [18] collect_similar(::Array{Array{Any,1},1}, ::Base.Generator{Array{Array{Any,1},1},typeof(Mamba.mcmc_worker!)}) at ./array.jl:561
#  [19] map(::Function, ::Array{Array{Any,1},1}) at ./abstractarray.jl:1987
#  [20] pmap2(::Function, ::Array{Array{Any,1},1}) at /Users/tgordon/.julia/packages/Mamba/674DT/src/utils.jl:94
#  [21] mcmc_master!(::Model, ::UnitRange{Int64}, ::Int64, ::Int64, ::UnitRange{Int64}, ::Bool) at /Users/tgordon/.julia/packages/Mamba/674DT/src/model/mcmc.jl:53
#  [22] #mcmc#23(::Int64, ::Int64, ::Int64, ::Bool, ::Function, ::Model, ::Dict{Symbol,Any}, ::Array{Dict{Symbol,Any},1}, ::Int64) at /Users/tgordon/.julia/packages/Mamba/674DT/src/model/mcmc.jl:33
#  [23] (::getfield(Mamba, Symbol("#kw##mcmc")))(::NamedTuple{(:burnin, :chains),Tuple{Int64,Int64}}, ::typeof(mcmc), ::Model, ::Dict{Symbol,Any}, ::Array{Dict{Symbol,Any},1}, ::Int64) at ./none:0
#  [24] f(::String) at ./In[3]:107
#  [25] iterate at ./generator.jl:47 [inlined]
#  [26] _collect(::Array{String,1}, ::Base.Generator{Array{String,1},typeof(f)}, ::Base.EltypeUnknown, ::Base.HasShape{1}) at ./array.jl:632
#  [27] collect_similar(::Array{String,1}, ::Base.Generator{Array{String,1},typeof(f)}) at ./array.jl:561
#  [28] map(::Function, ::Array{String,1}) at ./abstractarray.jl:1987
#  [29] top-level scope at In[3]:110
