# %%
include("../src/celerite.jl")
include("../TransitModel/transit.jl")
using Plots
using Statistics
using ForwardDiff
using LaTeXStrings
using LinearAlgebra
using DelimitedFiles

# %%
function make_gp(t, log_s, log_w0, log_var; bins=nothing, A0=nothing, ds0dlam=1, c=nothing)
    if bins != nothing 
        f = [sum(bins[1:i]) for i in 0:length(bins)]
        var = [exp(log_var)/b for b in bins]
        if c == nothing
            c = [(A0+ds0dlam*(f[i+1]+f[i]))/(A0+ds0dlam*(2*sum(f[2:end-1])+1)) for i in 1:length(bins)]*length(bins)
        else
            c = c./mean(c)
        end
        m = length(c)
        Q = broadcast(*, c, c')
        wn_vec = zeros(length(t)*m)
        for i in 1:m
            wn_vec[i:m:end] .= sqrt.(var[i]) 
        end
    else
        Q = ones(1, 1)
        c = nothing
    end
    log_q = log(1/sqrt(2))
    if bins != nothing
        gp = celerite.Celerite(celerite.SHOTerm(log_s, log_q, log_w0), Q)
        logD = celerite.compute!(gp, t, wn_vec)
    else
        gp = celerite.Celerite(celerite.SHOTerm(log_s, log_q, log_w0))
        logD = celerite.compute!(gp, t, exp.(0.5*log_var))
    end
    return gp, log_var, c
end

function trapezoidal_transit(t, t0, r, d, tin)
    trans = zeros(Real, length(t))
    t1 = (t0-d/2-tin)
    t2 = (t0-d/2)
    t3 = (t0+d/2)
    t4 = (t0+d/2+tin)
    intransit = (t.<=t3).&(t.>=t2)
    ingress = (t.<t2).&(t.>t1)
    egress = (t.<t4).&(t.>t3)
    trans[intransit] .= -(r^2)
    trans[ingress] .= -(t[ingress].-t1)*(r^2)/tin
    trans[egress] .= (1 - (r^2)).+(t[egress].-t3)*(r^2)/tin.-1
    return trans
end
# Out:
# trapezoidal_transit (generic function with 1 method)

# %%
# define parameters for mcmc run 

t = collect(-4:0.01:4)

t0 = 0
b0 = 0
rp = 0.1
d = 0.5
tin = d/3
u = [0.5, 0.5]
x0 = [t0, rp, d, tin]

log_s = collect(-25:1:0)
w0T = 10
log_w0 = log(w0T) - log(d)
log_var = -16
# Out:
# -16

# %%
# simulate data for mcmc run
io_mono = open("mcmc_data/short_timescale/input/params_mono.in", "a")
io_poly = open("mcmc_data/short_timescale/input/params_poly.in", "a")
c = zeros(2)
for (i, ls) in enumerate(log_s)
    monogp, _, _ = make_gp(t, ls-log_w0, log_w0, log_var) 
    polygp, log_wn, c = make_gp(t, ls-log_w0, log_w0, log_var, bins=[1/2, 1/2], c=[1, 2])
    monoy = celerite.simulate_gp(monogp, randn(length(t))) .+ trapezoidal_transit(t, x0...)[1]
    polyy = celerite.simulate_gp(polygp, randn(2*length(t))) .+ kron(ones(2)',trapezoidal_transit(t, x0...)[1])'
    writedlm("mcmc_data/short_timescale/input/transit_mono_$(i)", hcat(t, monoy))
    writedlm("mcmc_data/short_timescale/input/transit_poly_$(i)", hcat(t, polyy'))
    writedlm(io_mono, [0.5*log_var, rp, d, ls, 1/sqrt(2), log_w0, t0]')
    writedlm(io_poly, [sqrt(2)*0.5*log_var, sqrt(2)*0.5*log_var, c1, c2, rp, d, ls, 1/sqrt(2), log_w0, t0]')
end
log_wn = 0.5*log_var
c1, c2 = c[1], c[2]
writedlm("mcmc_data/short_timescale/input/codes.in", [collect(1:1:length(log_s))]')
close(io_mono)
close(io_poly)

# %%
data = readdlm("mcmc_data/short_timescale/input/transit_mono_8")
t = data[:,1]
flux = data[:,2]
plot(t, flux)

# %%
gp, _, _ = make_gp(t, log_s-log_w0, log_w0, log_var[14])
t0 = collect(-0.1:0.001:0.1)
like = zeros(length(t0))
for (i, c) in enumerate(t0)
    x0[1] = c
    trans = transit(t, x0...)[1]
    r = flux-trans
    like[i] = celerite.log_likelihood(gp, r)
end

# %%
plot(t0, like, legend=false)
plot!(t0, 1666.93 .-10500*((t0).^2), xlims=(-0.01, 0.01), ylims=(1665, 1670))
